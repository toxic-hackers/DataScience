# %% [markdown]
# # Pandas Dataframe to Google Firestore
#
# On my recent Hacker News project I ended up building a few nested data views in my pandas dataframe. These views are for plotting the user's comment sentiment over time, and for their top 50 saltiest comments.
#
# I needed to find somewhere to host this data for the front end app and after looking over every offering across AWS/Heroku/GoogleCloud I settled on Google Cloud's Cloud Firestore.
#
# The price and usability was hard to beat, but the system lacks a simple `csv` upload. And since I had nested values in my dataframe as `str(dict)`s I wanted to un-nest them and take advantage of the document based structure of Google Firestore.
#
# This un-nesting string method would work for MongoDB as well.
#
# The primary advantage of using Firestore is that I won't have to worry about building a scalable API, and the cost of storage/querying is very low.
#
# An added advantage is that my front-end dev partners can write all the code they'd like in JS, and I can write and interact with the database using Python. That's a major win.

# %% [markdown]
# ## Set up the Google Cloud Environment
#
# I recommend using the [Firestore Quickstart Tutorials](https://cloud.google.com/firestore/docs/quickstart-servers) to get started. You will need to get registered on Google Cloud Platform, and create a Google Cloud Platform project.
#
# Follow the instructions to create your database and download the authentication credential (`.json`).
#
# Then you will need to set your environment variable as well. If you're using jupyter like me you can put the key in the same folder as your notebook (**ADD THE FILE NAME TO YOUR GITIGNORE**) and then follow the steps below to add the key to your Anaconda env.
#
# Via Bash:
# ```
# cd $CONDA_PREFIX
# ls
# mkdir -p ./etc/conda/activate.d
# mkdir -p ./etc/conda/deactivate.d
# touch ./etc/conda/activate.d/env_vars.sh
# touch ./etc/conda/deactivate.d/env_vars.sh
# nano ./etc/conda/activate.d/env_vars.sh
# ```
# add these lines:
# ```
# #!/bin/sh
# export GOOGLE_APPLICATION_CREDENTIALS="yourkey.json"
# ```
# then ctrl+x, y.
# ```
# nano ./etc/conda/deactivate.d/env_vars.s
# ```
# add these lines:
# ```
# #!/bin/sh
# unset GOOGLE_APPLICATION_CREDENTIALS
# ```
#
# *Then you're ready to launch your Jupyter notebook.*

# %% [markdown]
# ## Load dependencies

# %%
#!pip install --upgrade google-cloud-firestore
import pandas as pd
import numpy as np
import json
import datetime
from google.cloud import firestore
from tqdm import tqdm_pandas
from tqdm import tqdm_notebook as tqdm
# Load TQDM
tqdm_pandas(tqdm())
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# TqdmDeprecationWarning: Please use `tqdm.pandas(...)` instead of `tqdm_pandas(tqdm(...))`.

# %% [markdown]
# ## Check for Env variable

# %%
# !if [ -z ${GOOGLE_APPLICATION_CREDENTIALS+x} ]; then echo "GOOGLE_APPLICATION_CREDENTIALS is unset"; else echo "GOOGLE_APPLICATION_CREDENTIALS is set to '$GOOGLE_APPLICATION_CREDENTIALS'";fi
# Out:
# GOOGLE_APPLICATION_CREDENTIALS is set to 'toxic-hackers-firebase-adminsdk-ss814-89fb3a76b5.json'

# %% [markdown]
# ## Initialize Cloud Firestore

# %%
db = firestore.Client()

# %% [markdown]
# ## I created the collection `commentor_stats` manually using the firestore dashboard.

# %%
users_ref = db.collection('commentor_stats')
users_ref

# %% [markdown]
# ## A few notes about creating new documents on Firestore
#
#  [The Google Cloud Tutorial for Uploading Data](https://cloud.google.com/firestore/docs/manage-data/add-data)
#
# #### Add a document with a specified document id using set
# ```db.collection(u'cities').document(u'new-city-id').set(data)```
#
# #### Let firestore create the id using the .add method.
# ```db.collection(u'cities').add(city.to_dict())```
#
# #### The data structure for creating proper imports.
# ```
# data = {
#   u'stringExample': u'Hello, World!',
#   u'booleanExample': True,
#   u'numberExample': 3.14159265,
#   u'dateExample': datetime.datetime.now(), #pd.timestamp works too.
#   u'arrayExample': [5, True, u'hello'],
#   u'nullExample': None,
#   u'objectExample': {
#     u'a': 5,
#     u'b': True
#   }
# ```
#
#
# #### Timestamps need to conform to RFC 3339, pd.Timestamp works.

# %% [markdown]
# ## Now it's time to upload all my data.  First I need to import it to the notebook.

# %%
df = pd.read_csv("Final_Data2/hn_commentor_summary.csv")

# %%
df.sort_values(by = ["sum_slt_s"], ascending = True).head()
# Out:
#            commentor  count_comments  time_of_last_comment  \
# 13791          DanBC           20405            1548967920
# 357216       tptacek           47283            1548999272
# 279573  pg_is_a_butt             857            1510157764
# 45281       TeMPOraL           18572            1549012070
# 109540       coldtea           20654            1549011451
#
#         time_of_first_comment  \
# 13791              1316712464
# 357216             1193928765
# 279573             1386703885
# 45281              1280659106
# 109540             1360252206
#
#                                              monthly_plot  \
# 13791   [{'y_m': '11_09', 't_s': 0.0, 't_h': 18.99, 'c...
# 357216  [{'y_m': '07_11', 't_s': 0.0, 't_h': 7.0, 'c_s...
# 279573  [{'y_m': '13_12', 't_s': -5.53, 't_h': 4.0, 'c...
# 45281   [{'y_m': '10_08', 't_s': 0.0, 't_h': 2.0, 'c_s...
# 109540  [{'y_m': '13_02', 't_s': -9.9, 't_h': 196.41, ...
#
#                                               top_cmnts_s  \
# 13791   [{'commentor': 'DanBC', 'comment_time': 144447...
# 357216  [{'commentor': 'tptacek', 'comment_time': 1393...
# 279573  [{'commentor': 'pg_is_a_butt', 'comment_time':...
# 45281   [{'commentor': 'TeMPOraL', 'comment_time': 147...
# 109540  [{'commentor': 'coldtea', 'comment_time': 1502...
#
#                                         top_salty_comment  sum_slt_oall  \
# 13791   [{'commentor': 'DanBC', 'comment_time': 144447...  18309.592278
# 357216  [{'commentor': 'tptacek', 'comment_time': 1393...  45022.323581
# 279573  [{'commentor': 'pg_is_a_butt', 'comment_time':...   -408.516125
# 45281   [{'commentor': 'TeMPOraL', 'comment_time': 147...  17212.187029
# 109540  [{'commentor': 'coldtea', 'comment_time': 1502...  19432.280883
#
#         average_slt_oall  min_slt_oall  max_slt_oall  cnt_slt_h  cnt_slt_s  \
# 13791           0.897309     -2.516190      0.999436    19516.0      889.0
# 357216          0.952188     -2.967871      0.999432    46298.0      985.0
# 279573         -0.476682     -3.099355      0.999432      367.0      490.0
# 45281           0.926782     -2.803237      0.999434    17985.0      587.0
# 109540          0.940848     -1.988798      0.999435    20112.0      542.0
#
#            sum_slt_h    sum_slt_s  avg_slt_h  avg_slt_s  rank_lt_amt_slt  \
# 13791   19395.023400 -1085.431121   0.993801  -1.220957              1.0
# 357216  46098.805516 -1076.481936   0.995698  -1.092875              2.0
# 279573    359.658917  -768.175042   0.979997  -1.567704              3.0
# 45281   17837.573015  -625.385987   0.991803  -1.065394              4.0
# 109540  20003.497742  -571.216859   0.994605  -1.053906              5.0
#
#         rank_lt_qty_sc  rank_oall_slt
# 13791              2.0            NaN
# 357216             1.0            NaN
# 279573             6.0            1.0
# 45281              3.0            NaN
# 109540             4.0            NaN

# %%
df.columns
# Out:
# Index(['commentor', 'count_comments', 'time_of_last_comment',
#        'time_of_first_comment', 'monthly_plot', 'top_cmnts_s',
#        'top_salty_comment', 'sum_slt_oall', 'average_slt_oall', 'min_slt_oall',
#        'max_slt_oall', 'cnt_slt_h', 'cnt_slt_s', 'sum_slt_h', 'sum_slt_s',
#        'avg_slt_h', 'avg_slt_s', 'rank_lt_amt_slt', 'rank_lt_qty_sc',
#        'rank_oall_slt'],
#       dtype='object')

# %%
# Rename a few columns for consistency. 
df = df.rename(columns={'count_comments': "cnt_cmnts_oall",
                        'time_of_last_comment': "time_cmnt_lst",
                        'time_of_first_comment': "time_cmnt_fst",
                        'average_slt_oall': "avg_slt_oall"})

# %%
### These are the columns I'll keep. I'm going to drop a few. 
df = df[["commentor", # Name of commentor.
  "time_cmnt_lst", # Most recent comment time in Dataset.
  "time_cmnt_fst", # First HN comment time.
  "cnt_cmnts_oall", # Count of total number of comments. 
  "sum_slt_oall", # Total Salt Score Overall. (All Salty + NonSalty Scores added up.)
  "avg_slt_oall", # Average Comment Salt Score across all comments. 
  "cnt_slt_s", # Count of JUST salty comments. 
  "sum_slt_s", # Total Salt Score of Salty Comments
  "avg_slt_s", # Average Salt Score of Salty Comments
  "rank_lt_amt_slt", # Rank: Lifetime Salt Scores Total of Salty comments only.
  "rank_lt_qty_sc", # Rank: Lifetime quantity of "Salty Comments" contributed.
  "rank_oall_slt", # Rank: Lifetime overall "Salt Score" total of All Salty + NonSalty comments.
  "top_cmnts_s", # List of 50 Top Salty Comments. 
  "monthly_plot"]];# List of every month of activity for plotting.

# %% [markdown]
# ### I'll make a copy incase something happens.

# %%
df["commentor_search"] = df["commentor"].str.lower()
df.head()
# Out:
#        commentor  time_cmnt_lst  time_cmnt_fst  cnt_cmnts_oall  sum_slt_oall  \
# 0             0-     1394798525     1394798525               1      0.999353
# 1  0--__-_-__--0     1541102045     1541102045               1      0.999393
# 2            0-0     1259867712     1259867712               1      0.999354
# 3            0-4     1288646410     1288394371              12     11.991090
# 4            0-9     1524324694     1477669562               2      1.997974
#
#    avg_slt_oall  cnt_slt_s  sum_slt_s  avg_slt_s  rank_lt_amt_slt  \
# 0      0.999353        NaN        NaN        NaN              NaN
# 1      0.999393        NaN        NaN        NaN              NaN
# 2      0.999354        NaN        NaN        NaN              NaN
# 3      0.999258        NaN        NaN        NaN              NaN
# 4      0.998987        NaN        NaN        NaN              NaN
#
#    rank_lt_qty_sc  rank_oall_slt top_cmnts_s  \
# 0             NaN            NaN         NaN
# 1             NaN            NaN         NaN
# 2             NaN            NaN         NaN
# 3             NaN            NaN         NaN
# 4             NaN            NaN         NaN
#
#                                         monthly_plot commentor_search
# 0  [{'y_m': '14_03', 't_s': 0.0, 't_h': 1.0, 'c_s...               0-
# 1  [{'y_m': '18_11', 't_s': 0.0, 't_h': 1.0, 'c_s...    0--__-_-__--0
# 2  [{'y_m': '09_12', 't_s': 0.0, 't_h': 1.0, 'c_s...              0-0
# 3  [{'y_m': '10_10', 't_s': 0.0, 't_h': 10.99, 'c...              0-4
# 4  [{'y_m': '16_10', 't_s': 0.0, 't_h': 1.0, 'c_s...              0-9

# %%
test = df.copy()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388118 entries, 0 to 388117
# Data columns (total 15 columns):
# commentor           388118 non-null object
# time_cmnt_lst       388118 non-null int64
# time_cmnt_fst       388118 non-null int64
# cnt_cmnts_oall      388118 non-null int64
# sum_slt_oall        388118 non-null float64
# avg_slt_oall        388118 non-null float64
# cnt_slt_s           51914 non-null float64
# sum_slt_s           51914 non-null float64
# avg_slt_s           51914 non-null float64
# rank_lt_amt_slt     51914 non-null float64
# rank_lt_qty_sc      51914 non-null float64
# rank_oall_slt       6168 non-null float64
# top_cmnts_s         51914 non-null object
# monthly_plot        388118 non-null object
# commentor_search    388118 non-null object
# dtypes: float64(8), int64(3), object(4)
# memory usage: 44.4+ MB

# %% [markdown]
# ### Convert Unix-Epoch times (currently `int`) to Pandas Timestamps.

# %%
# Convert Unix time to Timestamps
test["time_cmnt_lst"] = test["time_cmnt_lst"].apply(lambda x: pd.Timestamp(x, unit='s').tz_localize('UTC'))
test["time_cmnt_fst"] = test["time_cmnt_fst"].apply(lambda x: pd.Timestamp(x, unit='s').tz_localize('UTC'))
test.head(5)
# Out:
#        commentor             time_cmnt_lst             time_cmnt_fst  \
# 0             0- 2014-03-14 12:02:05+00:00 2014-03-14 12:02:05+00:00
# 1  0--__-_-__--0 2018-11-01 19:54:05+00:00 2018-11-01 19:54:05+00:00
# 2            0-0 2009-12-03 19:15:12+00:00 2009-12-03 19:15:12+00:00
# 3            0-4 2010-11-01 21:20:10+00:00 2010-10-29 23:19:31+00:00
# 4            0-9 2018-04-21 15:31:34+00:00 2016-10-28 15:46:02+00:00
#
#    cnt_cmnts_oall  sum_slt_oall  avg_slt_oall  cnt_slt_s  sum_slt_s  \
# 0               1      0.999353      0.999353        NaN        NaN
# 1               1      0.999393      0.999393        NaN        NaN
# 2               1      0.999354      0.999354        NaN        NaN
# 3              12     11.991090      0.999258        NaN        NaN
# 4               2      1.997974      0.998987        NaN        NaN
#
#    avg_slt_s  rank_lt_amt_slt  rank_lt_qty_sc  rank_oall_slt top_cmnts_s  \
# 0        NaN              NaN             NaN            NaN         NaN
# 1        NaN              NaN             NaN            NaN         NaN
# 2        NaN              NaN             NaN            NaN         NaN
# 3        NaN              NaN             NaN            NaN         NaN
# 4        NaN              NaN             NaN            NaN         NaN
#
#                                         monthly_plot commentor_search
# 0  [{'y_m': '14_03', 't_s': 0.0, 't_h': 1.0, 'c_s...               0-
# 1  [{'y_m': '18_11', 't_s': 0.0, 't_h': 1.0, 'c_s...    0--__-_-__--0
# 2  [{'y_m': '09_12', 't_s': 0.0, 't_h': 1.0, 'c_s...              0-0
# 3  [{'y_m': '10_10', 't_s': 0.0, 't_h': 10.99, 'c...              0-4
# 4  [{'y_m': '16_10', 't_s': 0.0, 't_h': 1.0, 'c_s...              0-9

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388118 entries, 0 to 388117
# Data columns (total 15 columns):
# commentor           388118 non-null object
# time_cmnt_lst       388118 non-null datetime64[ns, UTC]
# time_cmnt_fst       388118 non-null datetime64[ns, UTC]
# cnt_cmnts_oall      388118 non-null int64
# sum_slt_oall        388118 non-null float64
# avg_slt_oall        388118 non-null float64
# cnt_slt_s           51914 non-null float64
# sum_slt_s           51914 non-null float64
# avg_slt_s           51914 non-null float64
# rank_lt_amt_slt     51914 non-null float64
# rank_lt_qty_sc      51914 non-null float64
# rank_oall_slt       6168 non-null float64
# top_cmnts_s         51914 non-null object
# monthly_plot        388118 non-null object
# commentor_search    388118 non-null object
# dtypes: datetime64[ns, UTC](2), float64(8), int64(1), object(4)
# memory usage: 44.4+ MB

# %% [markdown]
# ## I'll use this function to unpack the messy list of comments from `top_cmnts_s' field.

# %%
test = test.sort_values(by = ["sum_slt_s"], ascending = True)
test.shape
# Out:
# (388118, 15)

# %%
# Here's what it looks like before unpacking/repacking:
test_cmnts = test.iloc[1]["top_cmnts_s"]
test_cmnts[0:1000]
# Out:
# '[{\'commentor\': \'tptacek\', \'comment_time\': 1393815150, \'comment_saltiness\': -2.967871080227196, \'is_salty\': True, \'is_severe_toxicity\': True, \'is_obscene\': True, \'is_identity_attack\': False, \'is_insult\': True, \'is_threat\': False, \'parent_type\': \'comment\', \'parent_author\': 7331783, \'parent_title\': \'Another Comment\', \'cleaned_comment\': \'Fuck L0ck. Seriously fuck those guys.\', \'comment_id\': 7331783, \'parent_id\': 7331604}, {\'commentor\': \'tptacek\', \'comment_time\': 1324960550, \'comment_saltiness\': -2.398391169384122, \'is_salty\': True, \'is_severe_toxicity\': False, \'is_obscene\': True, \'is_identity_attack\': False, \'is_insult\': True, \'is_threat\': False, \'parent_type\': \'comment\', \'parent_author\': 3394830, \'parent_title\': \'Another Comment\', \'cleaned_comment\': \'So great. "MOTHERFUCKERS!"\', \'comment_id\': 3394830, \'parent_id\': 3394742}, {\'commentor\': \'tptacek\', \'comment_time\': 1505572578, \'comment_saltiness\': -2.235194845050573, \'is_salty\': True, \'is_severe_toxicity\': False, \'is_obscene\': True, \'is_id'

# %%
t_df = pd.read_json(json.dumps(eval(test_cmnts)))
display(t_df.columns)
display(t_df.head())
# Out:
# Index(['cleaned_comment', 'comment_id', 'comment_saltiness', 'comment_time',
#        'commentor', 'is_identity_attack', 'is_insult', 'is_obscene',
#        'is_salty', 'is_severe_toxicity', 'is_threat', 'parent_author',
#        'parent_id', 'parent_title', 'parent_type'],
#       dtype='object')
#                                      cleaned_comment  comment_id  \
# 0              Fuck L0ck. Seriously fuck those guys.     7331783
# 1                         So great. "MOTHERFUCKERS!"     3394830
# 2  It's also fucking stupid. Peiter "mudge" Zatko...    15264806
# 3  Could you be more of a tool? Literally: the on...     5883501
# 4                           Kindly go fuck yourself.     6098474
#
#    comment_saltiness        comment_time commentor  is_identity_attack  \
# 0          -2.967871 2014-03-03 02:52:30   tptacek               False
# 1          -2.398391 2011-12-27 04:35:50   tptacek               False
# 2          -2.235195 2017-09-16 14:36:18   tptacek               False
# 3          -2.095188 2013-06-15 01:42:45   tptacek               False
# 4          -1.963429 2013-07-24 19:26:11   tptacek               False
#
#    is_insult  is_obscene  is_salty  is_severe_toxicity  is_threat  \
# 0       True        True      True                True      False
# 1       True        True      True               False      False
# 2       True        True      True               False      False
# 3       True        True      True               False      False
# 4       True        True      True               False      False
#
#    parent_author  parent_id     parent_title parent_type
# 0        7331783    7331604  Another Comment     comment
# 1        3394830    3394742  Another Comment     comment
# 2       15264806   15263080  Another Comment     comment
# 3        5883501    5883491  Another Comment     comment
# 4        6098474    6098462  Another Comment     comment

# %%
t_df = t_df.drop(columns=['commentor','is_salty']).reset_index()

# %%
def dict_top_comments(top_cmnt_obj):
    """Unpack the top comments and turn it into a good dict.
    
    Args:
        top_cmnt_obj, a str of dicts, from df.top_cmnts_s.
    
    Evaluates the string, json.dumps it, and reads it back in to a dataframe.
    Drops all unecessary columns. 
    Creates a named index for each comment. 
    Turns df into an indexed dict. 
    
    Returns: 
        temp, a properly formed nested dict. 
    """
    try:
        temp = pd.read_json(json.dumps(eval(top_cmnt_obj)))
        temp = temp.drop(columns=['commentor','is_salty']).reset_index()
        temp["c_id"] = temp["index"].apply(lambda x: "c_" + str(x))
        temp["comment_time"] = temp["comment_time"].apply(lambda x: pd.Timestamp(x, unit='s').tz_localize('UTC'))
        temp.drop(columns = ["index"], inplace = True)
        temp = temp.set_index("c_id").to_dict("index")
    except:
        temp = np.NaN
    return temp


# Preview the dict after unpacking & cleaning. 
unpacked_repacked = dict_top_comments(test_cmnts)
# After unpacking/repacking
unpacked_repacked["c_0"]
# Out:
# {'cleaned_comment': 'Fuck L0ck. Seriously fuck those guys.',
#  'comment_id': 7331783,
#  'comment_saltiness': -2.967871080227196,
#  'comment_time': Timestamp('2014-03-03 02:52:30+0000', tz='UTC'),
#  'is_identity_attack': False,
#  'is_insult': True,
#  'is_obscene': True,
#  'is_severe_toxicity': True,
#  'is_threat': False,
#  'parent_author': 7331783,
#  'parent_id': 7331604,
#  'parent_title': 'Another Comment',
#  'parent_type': 'comment'}

# %% [markdown]
# ## I'll use this function to unpack / repack my `monthly_plot`

# %%
# Before unpack/repack
test_plts = test.iloc[1]["monthly_plot"]
test_plts[0:1000]
# Out:
# "[{'y_m': '07_11', 't_s': 0.0, 't_h': 7.0, 'c_s': 0.0, 'c_h': 7.0}, {'y_m': '07_12', 't_s': -1.01, 't_h': 25.98, 'c_s': 1.0, 'c_h': 26.0}, {'y_m': '08_01', 't_s': -5.22, 't_h': 27.8, 'c_s': 4.0, 'c_h': 28.0}, {'y_m': '08_02', 't_s': -1.74, 't_h': 22.78, 'c_s': 1.0, 'c_h': 23.0}, {'y_m': '08_03', 't_s': -6.04, 't_h': 108.94, 'c_s': 6.0, 'c_h': 110.0}, {'y_m': '08_04', 't_s': -7.55, 't_h': 181.45, 'c_s': 6.0, 'c_h': 182.0}, {'y_m': '08_05', 't_s': -4.98, 't_h': 148.18, 'c_s': 5.0, 'c_h': 149.0}, {'y_m': '08_06', 't_s': -16.8, 't_h': 244.51, 'c_s': 13.0, 'c_h': 246.0}, {'y_m': '08_07', 't_s': -5.27, 't_h': 162.67, 'c_s': 5.0, 'c_h': 163.0}, {'y_m': '08_08', 't_s': -15.76, 't_h': 254.06, 'c_s': 14.0, 'c_h': 257.0}, {'y_m': '08_09', 't_s': -9.04, 't_h': 150.21, 'c_s': 8.0, 'c_h': 151.0}, {'y_m': '08_10', 't_s': -7.15, 't_h': 118.94, 'c_s': 6.0, 'c_h': 120.0}, {'y_m': '08_11', 't_s': -7.28, 't_h': 228.52, 'c_s': 6.0, 'c_h': 230.0}, {'y_m': '08_12', 't_s': -10.1, 't_h': 252.08, 'c_s': 8.0, 'c_"

# %%
def dict_monthly_plot(monthly_plot_obj):
    """Turns the list of dicts into a nested dict w/ indexes.
    
    Args:
        monthly_plot_obj, an array of dicts.
    
    Returns: 
        temp, a dict of dicts. 
    """
    try:
        temp = pd.DataFrame.from_dict(eval(monthly_plot_obj)).set_index("y_m").to_dict("index")
    except:
        temp = np.NaN
    return temp

unpacked_repacked = dict_monthly_plot(test_plts)
# After unpacking/repacking
unpacked_repacked['07_11']
# Out:
# {'c_h': 7.0, 'c_s': 0.0, 't_h': 7.0, 't_s': 0.0}

# %% [markdown]
# ## Finally, I'll use this function to process all the data for upload.
# This may take a while. :)
#
# I'll turn my df into a numpy array of dicts then apply the function.

# %%
upload = test.sort_values(by=['commentor']).to_dict("records")

# %%
len(upload)
# Out:
# 388118

# %%
#!pip install joblib
from joblib import Parallel, delayed
import multiprocessing
num_cores = multiprocessing.cpu_count()
num_cores
# Out:
# 12

# %%
x_dict = upload
def prep_for_upload(x):
    """"""
    x["monthly_plot"] = dict_monthly_plot(x["monthly_plot"]) # Processes the monthly plots 
    x["top_cmnts_s"] = dict_top_comments(x["top_cmnts_s"]) # Proceses the top comments
    #print("uploaded ", x["commentor"])
    return x
results =[]
results.append(Parallel(n_jobs=11)(delayed(prep_for_upload)(x) for x in tqdm(x_dict)))
print("done")
# Out:
# HBox(children=(IntProgress(value=0, max=388118), HTML(value='')))
# done

# %% [markdown]
# ##  This lets you set the start point incase you get interrupted and have to restart.

# %%
final = results[0]

# %%
len(final)
# Out:
# 388118

# %% [markdown]
# ## And here's the upload function.
#
# Notice how it batches the records into groups of 500 then submits them. The submission step was having the occasional timeout but adding the `try` worked great.

# %%
from time import sleep
x = 1
batch_no = 1
for entry in tqdm(final):
    if x == 1:
        # Do this part the first time.
        batch = db.batch()
        print("set batch")
        
    # Do this part for every single one. 
    #print ("added %s to batch" % x)
    batch.set(db.collection(u'commentor_stats').document(), entry)
    
    if x % 500 == 0:
        #Do this part every 500th time.
        #Had to add a try/except for this pesky submission error.
        try:
            batch.commit()
        except:
            print("Commit of batch %s failed... reattempting." % batch_no)
            sleep(5) # Wait 5 seconds, then retry. 
            batch.commit()
        print("sent batch %s" % batch_no)
        batch = db.batch()
        batch_no += 1
    x += 1

# One last batch commit to send the last non-500 docsize batch.
batch.commit()
# Out:
# HBox(children=(IntProgress(value=0, max=388118), HTML(value='')))
# set batch
# sent batch 1
# sent batch 2
# sent batch 3
# sent batch 4
# sent batch 5
# sent batch 6
# sent batch 7
# sent batch 8
# sent batch 9
# sent batch 10
# sent batch 11
# sent batch 12
# sent batch 13
# sent batch 14
# sent batch 15
# sent batch 16
# sent batch 17
# sent batch 18
# sent batch 19
# sent batch 20
# sent batch 21
# sent batch 22
# sent batch 23
# sent batch 24
# sent batch 25
# sent batch 26
# sent batch 27
# sent batch 28
# sent batch 29
# sent batch 30
# sent batch 31
# sent batch 32
# sent batch 33
# sent batch 34
# sent batch 35
# sent batch 36
# sent batch 37
# sent batch 38
# sent batch 39
# sent batch 40
# sent batch 41
# sent batch 42
# sent batch 43
# sent batch 44
# sent batch 45
# sent batch 46
# sent batch 47
# sent batch 48
# sent batch 49
# sent batch 50
# sent batch 51
# sent batch 52
# sent batch 53
# sent batch 54
# sent batch 55
# sent batch 56
# sent batch 57
# sent batch 58
# sent batch 59
# sent batch 60
# sent batch 61
# sent batch 62
# sent batch 63
# sent batch 64
# sent batch 65
# sent batch 66
# sent batch 67
# sent batch 68
# sent batch 69
# sent batch 70
# sent batch 71
# sent batch 72
# sent batch 73
# sent batch 74
# sent batch 75
# sent batch 76
# sent batch 77
# sent batch 78
# sent batch 79
# sent batch 80
# sent batch 81
# sent batch 82
# sent batch 83
# sent batch 84
# sent batch 85
# sent batch 86
# sent batch 87
# sent batch 88
# sent batch 89
# sent batch 90
# sent batch 91
# sent batch 92
# sent batch 93
# sent batch 94
# sent batch 95
# sent batch 96
# sent batch 97
# sent batch 98
# sent batch 99
# sent batch 100
# sent batch 101
# sent batch 102
# sent batch 103
# sent batch 104
# sent batch 105
# sent batch 106
# sent batch 107
# sent batch 108
# sent batch 109
# sent batch 110
# sent batch 111
# sent batch 112
# sent batch 113
# sent batch 114
# sent batch 115
# sent batch 116
# sent batch 117
# sent batch 118
# sent batch 119
# sent batch 120
# sent batch 121
# sent batch 122
# sent batch 123
# sent batch 124
# sent batch 125
# sent batch 126
# sent batch 127
# sent batch 128
# sent batch 129
# sent batch 130
# sent batch 131
# sent batch 132
# sent batch 133
# sent batch 134
# sent batch 135
# sent batch 136
# sent batch 137
# sent batch 138
# sent batch 139
# sent batch 140
# sent batch 141
# sent batch 142
# sent batch 143
# sent batch 144
# sent batch 145
# sent batch 146
# sent batch 147
# sent batch 148
# sent batch 149
# sent batch 150
# sent batch 151
# sent batch 152
# sent batch 153
# sent batch 154
# sent batch 155
# sent batch 156
# sent batch 157
# sent batch 158
# sent batch 159
# sent batch 160
# sent batch 161
# sent batch 162
# sent batch 163
# sent batch 164
# sent batch 165
# sent batch 166
# sent batch 167
# sent batch 168
# sent batch 169
# sent batch 170
# sent batch 171
# sent batch 172
# sent batch 173
# sent batch 174
# sent batch 175
# sent batch 176
# sent batch 177
# sent batch 178
# sent batch 179
# sent batch 180
# sent batch 181
# sent batch 182
# sent batch 183
# sent batch 184
# sent batch 185
# sent batch 186
# sent batch 187
# sent batch 188
# sent batch 189
# sent batch 190
# sent batch 191
# sent batch 192
# sent batch 193
# sent batch 194
# sent batch 195
# sent batch 196
# sent batch 197
# sent batch 198
# sent batch 199
# sent batch 200
# sent batch 201
# sent batch 202
# sent batch 203
# sent batch 204
# sent batch 205
# sent batch 206
# sent batch 207
# sent batch 208
# sent batch 209
# sent batch 210
# sent batch 211
# sent batch 212
# sent batch 213
# sent batch 214
# sent batch 215
# sent batch 216
# sent batch 217
# sent batch 218
# sent batch 219
# sent batch 220
# sent batch 221
# sent batch 222
# sent batch 223
# sent batch 224
# sent batch 225
# sent batch 226
# sent batch 227
# sent batch 228
# sent batch 229
# sent batch 230
# sent batch 231
# sent batch 232
# sent batch 233
# sent batch 234
# sent batch 235
# sent batch 236
# sent batch 237
# sent batch 238
# sent batch 239
# sent batch 240
# sent batch 241
# sent batch 242
# sent batch 243
# sent batch 244
# sent batch 245
# sent batch 246
# sent batch 247
# sent batch 248
# sent batch 249
# sent batch 250
# sent batch 251
# sent batch 252
# sent batch 253
# sent batch 254
# sent batch 255
# sent batch 256
# sent batch 257
# sent batch 258
# sent batch 259
# sent batch 260
# sent batch 261
# sent batch 262
# sent batch 263
# sent batch 264
# sent batch 265
# sent batch 266
# sent batch 267
# sent batch 268
# sent batch 269
# sent batch 270
# sent batch 271
# sent batch 272
# sent batch 273
# sent batch 274
# sent batch 275
# sent batch 276
# sent batch 277
# sent batch 278
# sent batch 279
# sent batch 280
# sent batch 281
# sent batch 282
# sent batch 283
# sent batch 284
# sent batch 285
# sent batch 286
# sent batch 287
# sent batch 288
# sent batch 289
# sent batch 290
# sent batch 291
# sent batch 292
# sent batch 293
# sent batch 294
# sent batch 295
# sent batch 296
# sent batch 297
# sent batch 298
# sent batch 299
# sent batch 300
# sent batch 301
# sent batch 302
# sent batch 303
# sent batch 304
# sent batch 305
# sent batch 306
# sent batch 307
# sent batch 308
# sent batch 309
# sent batch 310
# sent batch 311
# sent batch 312
# sent batch 313
# sent batch 314
# sent batch 315
# sent batch 316
# sent batch 317
# sent batch 318
# sent batch 319
# sent batch 320
# sent batch 321
# sent batch 322
# sent batch 323
# sent batch 324
# sent batch 325
# sent batch 326
# sent batch 327
# sent batch 328
# sent batch 329
# sent batch 330
# sent batch 331
# sent batch 332
# sent batch 333
# sent batch 334
# sent batch 335
# sent batch 336
# sent batch 337
# sent batch 338
# sent batch 339
# sent batch 340
# sent batch 341
# sent batch 342
# sent batch 343
# sent batch 344
# sent batch 345
# sent batch 346
# sent batch 347
# sent batch 348
# sent batch 349
# sent batch 350
# sent batch 351
# sent batch 352
# sent batch 353
# sent batch 354
# sent batch 355
# sent batch 356
# sent batch 357
# sent batch 358
# sent batch 359
# sent batch 360
# sent batch 361
# sent batch 362
# sent batch 363
# sent batch 364
# sent batch 365
# sent batch 366
# sent batch 367
# sent batch 368
# sent batch 369
# sent batch 370
# sent batch 371
# sent batch 372
# sent batch 373
# sent batch 374
# sent batch 375
# sent batch 376
# sent batch 377
# sent batch 378
# sent batch 379
# sent batch 380
# sent batch 381
# sent batch 382
# sent batch 383
# sent batch 384
# sent batch 385
# sent batch 386
# sent batch 387
# sent batch 388
# sent batch 389
# sent batch 390
# sent batch 391
# sent batch 392
# sent batch 393
# sent batch 394
# sent batch 395
# sent batch 396
# sent batch 397
# sent batch 398
# sent batch 399
# sent batch 400
# sent batch 401
# sent batch 402
# sent batch 403
# sent batch 404
# sent batch 405
# sent batch 406
# sent batch 407
# sent batch 408
# sent batch 409
# sent batch 410
# sent batch 411
# sent batch 412
# sent batch 413
# sent batch 414
# sent batch 415
# sent batch 416
# sent batch 417
# sent batch 418
# sent batch 419
# sent batch 420
# sent batch 421
# sent batch 422
# sent batch 423
# sent batch 424
# sent batch 425
# sent batch 426
# sent batch 427
# sent batch 428
# sent batch 429
# sent batch 430
# sent batch 431
# sent batch 432
# sent batch 433
# sent batch 434
# sent batch 435
# sent batch 436
# sent batch 437
# sent batch 438
# sent batch 439
# sent batch 440
# sent batch 441
# sent batch 442
# sent batch 443
# sent batch 444
# sent batch 445
# sent batch 446
# sent batch 447
# sent batch 448
# sent batch 449
# sent batch 450
# sent batch 451
# sent batch 452
# sent batch 453
# sent batch 454
# sent batch 455
# sent batch 456
# sent batch 457
# sent batch 458
# sent batch 459
# sent batch 460
# sent batch 461
# sent batch 462
# sent batch 463
# sent batch 464
# sent batch 465
# sent batch 466
# sent batch 467
# sent batch 468
# sent batch 469
# sent batch 470
# sent batch 471
# sent batch 472
# sent batch 473
# sent batch 474
# sent batch 475
# sent batch 476
# sent batch 477
# sent batch 478
# sent batch 479
# sent batch 480
# sent batch 481
# sent batch 482
# sent batch 483
# sent batch 484
# sent batch 485
# sent batch 486
# sent batch 487
# sent batch 488
# sent batch 489
# sent batch 490
# sent batch 491
# sent batch 492
# sent batch 493
# sent batch 494
# sent batch 495
# sent batch 496
# sent batch 497
# sent batch 498
# sent batch 499
# sent batch 500
# sent batch 501
# sent batch 502
# sent batch 503
# sent batch 504
# sent batch 505
# sent batch 506
# sent batch 507
# sent batch 508
# sent batch 509
# sent batch 510
# sent batch 511
# sent batch 512
# sent batch 513
# sent batch 514
# sent batch 515
# sent batch 516
# sent batch 517
# sent batch 518
# sent batch 519
# sent batch 520
# sent batch 521
# sent batch 522
# sent batch 523
# sent batch 524
# sent batch 525
# sent batch 526
# sent batch 527
# sent batch 528
# sent batch 529
# sent batch 530
# sent batch 531
# sent batch 532
# sent batch 533
# sent batch 534
# sent batch 535
# sent batch 536
# sent batch 537
# sent batch 538
# sent batch 539
# sent batch 540
# sent batch 541
# sent batch 542
# sent batch 543
# sent batch 544
# sent batch 545
# sent batch 546
# sent batch 547
# sent batch 548
# sent batch 549
# sent batch 550
# sent batch 551
# sent batch 552
# sent batch 553
# sent batch 554
# sent batch 555
# sent batch 556
# sent batch 557
# sent batch 558
# sent batch 559
# sent batch 560
# sent batch 561
# sent batch 562
# sent batch 563
# sent batch 564
# sent batch 565
# sent batch 566
# sent batch 567
# sent batch 568
# sent batch 569
# sent batch 570
# sent batch 571
# sent batch 572
# sent batch 573
# sent batch 574
# sent batch 575
# sent batch 576
# sent batch 577
# sent batch 578
# sent batch 579
# sent batch 580
# sent batch 581
# sent batch 582
# sent batch 583
# sent batch 584
# sent batch 585
# sent batch 586
# sent batch 587
# sent batch 588
# sent batch 589
# sent batch 590
# sent batch 591
# sent batch 592
# sent batch 593
# sent batch 594
# sent batch 595
# sent batch 596
# sent batch 597
# sent batch 598
# sent batch 599
# sent batch 600
# sent batch 601
# sent batch 602
# sent batch 603
# sent batch 604
# sent batch 605
# sent batch 606
# sent batch 607
# sent batch 608
# sent batch 609
# sent batch 610
# sent batch 611
# sent batch 612
# sent batch 613
# sent batch 614
# sent batch 615
# sent batch 616
# sent batch 617
# sent batch 618
# sent batch 619
# sent batch 620
# sent batch 621
# sent batch 622
# sent batch 623
# sent batch 624
# sent batch 625
# sent batch 626
# sent batch 627
# sent batch 628
# sent batch 629
# sent batch 630
# sent batch 631
# sent batch 632
# sent batch 633
# sent batch 634
# sent batch 635
# sent batch 636
# sent batch 637
# sent batch 638
# sent batch 639
# sent batch 640
# sent batch 641
# sent batch 642
# sent batch 643
# sent batch 644
# sent batch 645
# sent batch 646
# sent batch 647
# sent batch 648
# sent batch 649
# sent batch 650
# sent batch 651
# sent batch 652
# sent batch 653
# sent batch 654
# sent batch 655
# sent batch 656
# sent batch 657
# sent batch 658
# sent batch 659
# sent batch 660
# sent batch 661
# sent batch 662
# sent batch 663
# sent batch 664
# sent batch 665
# sent batch 666
# sent batch 667
# sent batch 668
# sent batch 669
# sent batch 670
# sent batch 671
# sent batch 672
# sent batch 673
# sent batch 674
# sent batch 675
# sent batch 676
# sent batch 677
# sent batch 678
# sent batch 679
# sent batch 680
# sent batch 681
# sent batch 682
# sent batch 683
# sent batch 684
# sent batch 685
# sent batch 686
# sent batch 687
# sent batch 688
# sent batch 689
# sent batch 690
# sent batch 691
# sent batch 692
# sent batch 693
# sent batch 694
# sent batch 695
# sent batch 696
# sent batch 697
# sent batch 698
# sent batch 699
# sent batch 700
# sent batch 701
# sent batch 702
# sent batch 703
# sent batch 704
# sent batch 705
# sent batch 706
# sent batch 707
# sent batch 708
# sent batch 709
# sent batch 710
# sent batch 711
# sent batch 712
# sent batch 713
# sent batch 714
# sent batch 715
# sent batch 716
# sent batch 717
# sent batch 718
# sent batch 719
# sent batch 720
# sent batch 721
# sent batch 722
# sent batch 723
# sent batch 724
# sent batch 725
# sent batch 726
# sent batch 727
# sent batch 728
# sent batch 729
# sent batch 730
# sent batch 731
# sent batch 732
# sent batch 733
# sent batch 734
# sent batch 735
# sent batch 736
# sent batch 737
# sent batch 738
# sent batch 739
# sent batch 740
# sent batch 741
# sent batch 742
# sent batch 743
# sent batch 744
# sent batch 745
# sent batch 746
# sent batch 747
# sent batch 748
# sent batch 749
# sent batch 750
# sent batch 751
# sent batch 752
# sent batch 753
# sent batch 754
# sent batch 755
# sent batch 756
# sent batch 757
# sent batch 758
# sent batch 759
# sent batch 760
# sent batch 761
# sent batch 762
# sent batch 763
# sent batch 764
# sent batch 765
# sent batch 766
# sent batch 767
# sent batch 768
# sent batch 769
# sent batch 770
# sent batch 771
# sent batch 772
# sent batch 773
# sent batch 774
# sent batch 775
# sent batch 776
# [update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }, update_time {
#    seconds: 1558029224
#    nanos: 125285000
#  }]

# %%
batch.commit()
# Out:
# [update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }, update_time {
#    seconds: 1557775181
#    nanos: 939366000
#  }]

# %%
# The basic outline for batch uploading. 
#batch = db.batch()
#batch.set(db.collection(u'commentor_stats').document(),{u'commentor': u'ZTESTZZZZZ'})
#batch.commit()
